# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
d = pd.read_csv('HTRU_2.csv', header=None)
print(d)
x = d.loc[d[8]==0,0]
print(x)
# Out:
#                 0          1         2         3           4          5  \
# 0      140.562500  55.683782 -0.234571 -0.699648    3.199833  19.110426
# 1      102.507812  58.882430  0.465318 -0.515088    1.677258  14.860146
# 2      103.015625  39.341649  0.323328  1.051164    3.121237  21.744669
# 3      136.750000  57.178449 -0.068415 -0.636238    3.642977  20.959280
# 4       88.726562  40.672225  0.600866  1.123492    1.178930  11.468720
# ...           ...        ...       ...       ...         ...        ...
# 17893  136.429688  59.847421 -0.187846 -0.738123    1.296823  12.166062
# 17894  122.554688  49.485605  0.127978  0.323061   16.409699  44.626893
# 17895  119.335938  59.935939  0.159363 -0.743025   21.430602  58.872000
# 17896  114.507812  53.902400  0.201161 -0.024789    1.946488  13.381731
# 17897   57.062500  85.797340  1.406391  0.089520  188.306020  64.712562
#
#                6           7  8
# 0       7.975532   74.242225  0
# 1      10.576487  127.393580  0
# 2       7.735822   63.171909  0
# 3       6.896499   53.593661  0
# 4      14.269573  252.567306  0
# ...          ...         ... ..
# 17893  15.450260  285.931022  0
# 17894   2.945244    8.297092  0
# 17895   2.499517    4.595173  0
# 17896  10.007967  134.238910  0
# 17897  -1.597527    1.429475  0
#
# [17898 rows x 9 columns]
# 0        140.562500
# 1        102.507812
# 2        103.015625
# 3        136.750000
# 4         88.726562
#             ...
# 17893    136.429688
# 17894    122.554688
# 17895    119.335938
# 17896    114.507812
# 17897     57.062500
# Name: 0, Length: 16259, dtype: float64

# %% [markdown]
# # Problem 1

# %%
mean_DMSNR_0 = d.loc[d[8]==0, 4]
mean_DMSNR_1 = d.loc[d[8]==1, 4]
fig, ax = plt.subplots(1,1)
ax.hist(mean_DMSNR_0, bins=30, density=True, alpha=0.5)
ax.hist(mean_DMSNR_1, bins=30, density=True, alpha=0.5)
plt.xlabel('DM-SNR Curve Mean')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
sd_DMSNR_0 = d.loc[d[8]==0, 5]
sd_DMSNR_1 = d.loc[d[8]==1, 5]
fig, ax = plt.subplots(1,1)
ax.hist(sd_DMSNR_0, bins=30, density=True, alpha=0.5)
ax.hist(sd_DMSNR_1, bins=30, density=True, alpha=0.5)
plt.xlabel('DM-SNR Curve Standard Deviation')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
ex_DMSNR_0 = d.loc[d[8]==0, 6]
ex_DMSNR_1 = d.loc[d[8]==1, 6]
fig, ax = plt.subplots(1,1)
ax.hist(ex_DMSNR_0, bins=30, density=True, alpha=0.5)
ax.hist(ex_DMSNR_1, bins=30, density=True, alpha=0.5)
plt.xlabel('DM-SNR Curve Excess Kurtosis')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
skew_DMSNR_0 = d.loc[d[8]==0, 7]
skew_DMSNR_1 = d.loc[d[8]==1, 7]
fig, ax = plt.subplots(1,1)
ax.hist(skew_DMSNR_0, bins=30, density=True, alpha=0.5)
ax.hist(skew_DMSNR_1, bins=30, density=True, alpha=0.5)
plt.xlabel('DM-SNR Curve Skew')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %% [markdown]
# # Problem 2

# %%
pos = d.loc[d[8]==1]
PA = len(pos)/len(d[8])
print('The probability of an observation being a pular candidate is P(A)=', PA)
# Out:
# The probability of an observation being a pular candidate is P(A)= 0.09157447759526204

# %%
mean80=d.loc[d[0]<=80]
PB = len(mean80)/len(d[0])
print('The probability that an observation with Mean of the integrated profile <80 is P(B)=', PB)
# Out:
# The probability that an observation with Mean of the integrated profile <80 is P(B)= 0.08626662196893507

# %%
PAnB = PA * PB
print('The probability that an observation satisfies both of the conditions above, A and B, is P(AnB)=', PAnB)
# Out:
# The probability that an observation satisfies both of the conditions above, A and B, is P(AnB)= 0.007899820840713185

# %% [markdown]
# # Problem 3

# %%
P_A_given_B = PAnB / PB
print('For an obersvation with mean of the integrated profile < 80, the probability that it is a pulsar candidate is', P_A_given_B)
# Out:
# For an obersvation with mean of the integrated profile < 80, the probability that it is a pulsar candidate is 0.09157447759526204

# %%
P_B_given_A = PAnB / PA
print('For a pulsar candidate, the probability that its Mean of the integrated profile < 80 is', P_B_given_A)
# Out:
# For a pulsar candidate, the probability that its Mean of the integrated profile < 80 is 0.08626662196893507
