# %%
import numpy as np

# %% [markdown]
# ### Q1. maximum likelihood estimation
# Using maximum likelihood estimation method to find the probability distribution function $f(x|a,b)=x0+ax+bx^2$
# which best describes the following dataset. <br>
#
# https://canvas.uw.edu/files/97611913/download?download_frd=1 <br>
#
# In this parameterization, $x_0$ is a function of $(a,b)$ and it normalizes the PDF $f(x|a,b)$ within range $x:[-1,1]$. <br>
# Find negative log likelihood value like we did in class but for $(a,b)$. Use dataset above as data point. <br>
# Procedure 1. Start with a broad range $a$ in $[-0.5, 0.5]$ (20 invervals evenly between this range) and $b$ in $[-0.5, 0.5]$ (20 intervales evenly between this range). <br>
# Procedure 2. Zoom in the countour range of $a$ in $[a_lower,a_upper]$ and $b$ in $[b_lower,b_upper]$. You are looking for a range when the negative log likelihood value of outer countour is roughly 2 greater than minimum  $−lnL_{max}=−lnL_{outercountour}+2$

# %% [markdown]
# 1. Draw the contour of negative log liklihood as function of (a,b). Results might looks similar to following (Adjust ranges in a and b to find optimal points). <br>
# ![image.png](attachment:61281901-52a9-4ffc-8600-c2d6ae78edf4.png)!

# %% [markdown]
# 2. Find the pair of parameter $(a_M,b_M)$ which provides maximum likelihood value. What is the value of $a_M$, $b_M$
# and the corresponding negative log likelihood value?

# %% [markdown]
# 3. Project data into 1 dimensional distribution and superpose with the best fit PDF $f(x|a_M,b_M)$.

# %% [markdown]
# 4. Following tutorial of the iminuit package below to obtain the best likelihood fit results. The iMinuit is very sensitive to the beginning parameter values and the range of each parameter. Make sure you set a range where negative log likelihood value is positive. Check consistency with your numerical solutions from Step 2. <br> https://iminuit.readthedocs.io/en/stable/notebooks/cost_functions.html

# %% [markdown]
# ### Q2. least quared method
# Using least quared method to find the line y=ax+b which best describes the following dataset. See example 114 of the textbook

# %%
import numpy as np

xd = np.array([1., 2., 3., 4., 5.])
yd = np.array([1.7, 2.3, 3.5, 3.3, 4.3])
yd_err = np.array([0.5, 0.3, 0.4, 0.4, 0.6])

# %% [markdown]
# 1. Using equation in example 114 to calculate the value of the slope a and interception b.

# %% [markdown]
# 2. Draw the data point (with vertical error bar) in the x-y plan and superpose with the best fit line. Results might look similar to the figure below.
# ![image.png](attachment:0b1e0fe1-8b5d-4928-b094-93e69d570907.png)

# %% [markdown]
# 3. Following tutorial of the iminuit package below to obtain the best fit results. Check consistenteny with your analytic solutions from Step 1.
# https://iminuit.readthedocs.io/en/stable/notebooks/generic_least_squares.html
